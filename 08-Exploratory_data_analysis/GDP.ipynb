# %% [markdown]
# # Análise exploratória de dados

# %% [markdown]
# Em estatística, a análise exploratória de dados (AED) é uma abordagem à análise de conjuntos de dados de modo a resumir suas características principais, frequentemente com métodos visuais.
# Primariamente a AED tem como objetivo observar o que os dados podem nos dizer além da modelagem formal ou do processo de teste de hipóteses.
#
# A análise exploratória de dados emprega grande variedade de técnicas gráficas e quantitativas, visando maximizar a obtenção de informações ocultas na sua estrutura, descobrir variáveis importantes em suas tendências, detectar comportamentos anômalos do fenômeno, testar se são válidas as hipóteses assumidas, escolher modelos e determinar o número ótimo de variáveis.

# %% [markdown]
# ## Objetivos principais:
# 1. Entender suas variáveis
# 2. Limpar seu dataset
# 3. Analisar relação entre as variáveis

# %% [markdown]
# # Dataset

# %% [markdown]
# ## Conhecendo os dados
#
# - Country
# - Region
# - Population
# - Area (sq. mi.)
# - Pop. Density (per sq. mi.)
# - Coastline (coast/area ratio)
# - Net migration
# - Infant mortality (per 1000 births)
# - GDP ($ per capita)

# %%
#Importando Bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.__version__
# Out:
# '0.10.0'

# %%
# !pip3 install --upgrade seaborn
# Out:
# Requirement already up-to-date: seaborn in /usr/local/lib/python3.7/site-packages (0.10.0)
# ...

# %%
#Carregando o dataset
paises = pd.read_csv('countries of the world.csv', decimal=',')

# %% [markdown]
# ## Olhando mais de perto o dataset

# %%
paises.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
paises.shape
# Out:
# (227, 20)

# %%
paises.columns
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
paises['Country'].unique()
# Out:
# array(['Afghanistan ', 'Albania ', 'Algeria ', 'American Samoa ',
#        'Andorra ', 'Angola ', 'Anguilla ', 'Antigua & Barbuda ',
#        'Argentina ', 'Armenia ', 'Aruba ', 'Australia ', 'Austria ',
#        'Azerbaijan ', 'Bahamas, The ', 'Bahrain ', 'Bangladesh ',
#        'Barbados ', 'Belarus ', 'Belgium ', 'Belize ', 'Benin ',
#        'Bermuda ', 'Bhutan ', 'Bolivia ', 'Bosnia & Herzegovina ',
#        'Botswana ', 'Brazil ', 'British Virgin Is. ', 'Brunei ',
#        'Bulgaria ', 'Burkina Faso ', 'Burma ', 'Burundi ', 'Cambodia ',
#        'Cameroon ', 'Canada ', 'Cape Verde ', 'Cayman Islands ',
#        'Central African Rep. ', 'Chad ', 'Chile ', 'China ', 'Colombia ',
#        'Comoros ', 'Congo, Dem. Rep. ', 'Congo, Repub. of the ',
#        'Cook Islands ', 'Costa Rica ', "Cote d'Ivoire ", 'Croatia ',
#        'Cuba ', 'Cyprus ', 'Czech Republic ', 'Denmark ', 'Djibouti ',
#        'Dominica ', 'Dominican Republic ', 'East Timor ', 'Ecuador ',
# ...

# %%
paises.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
# Country                               227 non-null object
# Region                                227 non-null object
# Population                            227 non-null int64
# Area (sq. mi.)                        227 non-null int64
# Pop. Density (per sq. mi.)            227 non-null float64
# Coastline (coast/area ratio)          227 non-null float64
# Net migration                         224 non-null float64
# Infant mortality (per 1000 births)    224 non-null float64
# GDP ($ per capita)                    226 non-null float64
# Literacy (%)                          209 non-null float64
# Phones (per 1000)                     223 non-null float64
# Arable (%)                            225 non-null float64
# Crops (%)                             225 non-null float64
# Other (%)                             225 non-null float64
# ...

# %%
paises.isnull().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                          18
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
paises[paises['Climate'].isnull()]
# Out:
#                    Country                               Region  Population  \
# 5                  Angola   SUB-SAHARAN AFRICA                     12127071
# 36                 Canada   NORTHERN AMERICA                       33098932
# 50                Croatia   EASTERN EUROPE                          4494749
# 66          Faroe Islands   WESTERN EUROPE                            47246
# 78              Gibraltar   WESTERN EUROPE                            27928
# 101                 Italy   WESTERN EUROPE                         58133509
# 115               Lebanon   NEAR EAST                               3874050
# 118                 Libya   NORTHERN AFRICA                         5900754
# 120             Lithuania   BALTICS                                 3585906
# 121            Luxembourg   WESTERN EUROPE                           474413
# 129                 Malta   WESTERN EUROPE                           400214
# ...

# %% [markdown]
# ## Tratamento de NaN

# %% [markdown]
# O método escolhido vai varia de cada caso.
# Opções:
#
# ```python
# df.dropna() # Apaga a linha que tiver uma informação NaN
# df.fillna() # Pode preencher com 0, moda, média, mediana
# df.bfill() #Vai preencher com último valor 'andando' da última linha para primeira
# df.ffill() #Vai preencher com último valor 'andando' da primeira linha para última
# ```

# %%
paises.describe()
# Out:
#          Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# count  2.270000e+02    2.270000e+02                  227.000000
# mean   2.874028e+07    5.982270e+05                  379.047137
# std    1.178913e+08    1.790282e+06                 1660.185825
# min    7.026000e+03    2.000000e+00                    0.000000
# 25%    4.376240e+05    4.647500e+03                   29.150000
# 50%    4.786994e+06    8.660000e+04                   78.800000
# 75%    1.749777e+07    4.418110e+05                  190.150000
# max    1.313974e+09    1.707520e+07                16271.500000
#
#        Coastline (coast/area ratio)  Net migration  \
# count                    227.000000     224.000000
# mean                      21.165330       0.038125
# std                       72.286863       4.889269
# min                        0.000000     -20.990000
# 25%                        0.100000      -0.927500
# 50%                        0.730000       0.000000
# ...

# %% [markdown]
# O describe nos traz uma primeira análise para entender como está distribuído nosso dado

# %% [markdown]
# ### Criar agrupamentos pode ajudar a achar padrões

# %%
grupos = paises.groupby('Region')[['Country','Population','Area (sq. mi.)', 'Literacy (%)']].agg({'Country':'count', 'Population':'sum','Area (sq. mi.)':'sum', 'Literacy (%)':'mean'})
grupos
# Out:
#                                      Country  Population  Area (sq. mi.)  \
# Region
# ASIA (EX. NEAR EAST)                      28  3687982236        23096712
# BALTICS                                    3     7184974          175015
# C.W. OF IND. STATES                       12   280081548        22100843
# EASTERN EUROPE                            12   119914717         1152222
# LATIN AMER. & CARIB                       45   561824599        20544084
# NEAR EAST                                 16   195068377         4355586
# NORTHERN AFRICA                            6   161407133         6018890
# NORTHERN AMERICA                           5   331672307        21782471
# OCEANIA                                   21    33131662         8519812
# SUB-SAHARAN AFRICA                        51   749437000        24341406
# WESTERN EUROPE                            28   396339998         3710478
#
#                                      Literacy (%)
# Region
# ...

# %% [markdown]
# ## Representação gráfica

# %%
plt.figure(figsize=(16, 6))
sns.distplot(paises['GDP ($ per capita)']);

# %%
plt.figure(figsize=(16, 6))
sns.distplot(paises['Infant mortality (per 1000 births)']);

# %%
ax = sns.boxplot(x = 'Infant mortality (per 1000 births)', data = paises, orient = 'h')
ax.figure.set_size_inches(12, 4)
ax.set_title('Infant mortality (per 1000 births)', fontsize=18)
ax

# %%
ax = sns.boxplot(x = 'Infant mortality (per 1000 births)', y='Region', data = paises, orient = 'h')
ax.figure.set_size_inches(12, 8)
ax.set_title('Infant mortality (per 1000 births)', fontsize=18)
ax

# %%
plt.figure(figsize=(16, 6))
chart = sns.barplot(data=paises.groupby('Region')[['GDP ($ per capita)']].mean().sort_values(by='GDP ($ per capita)').reset_index(), 
            x = 'Region', y='GDP ($ per capita)')
plt.setp(chart.get_xticklabels(), rotation=90)
plt.show()

# %%
plt.figure(figsize=(16, 6))
chart = sns.barplot(data=paises.groupby('Region')[['Population']].sum().sort_values(by='Population').reset_index(), 
            x = 'Region', y='Population')
plt.setp(chart.get_xticklabels(), rotation=90)
plt.show()

# %%
plt.figure(figsize=(16, 6))
chart = sns.barplot(data=paises.groupby('Region')[['Infant mortality (per 1000 births)']].sum().sort_values(by='Infant mortality (per 1000 births)').reset_index(), 
            x = 'Region', y='Infant mortality (per 1000 births)')
plt.setp(chart.get_xticklabels(), rotation=90)
plt.show()

# %% [markdown]
# # Quais hipóteses podemos levantar analisando essas relações?

# %%
sns.pairplot(paises,
             vars=['GDP ($ per capita)','Infant mortality (per 1000 births)', 'Birthrate','Agriculture'],
             hue='Region',
             diag_kind="hist")

# %%
sns.pairplot(paises,
             vars= ['GDP ($ per capita)','Phones (per 1000)', 'Literacy (%)','Service'],
             hue='Region',
             diag_kind="hist")

# %% [markdown]
# # Correlação

# %%
plt.figure(figsize=(10,10))
sns.heatmap(paises.corr())
plt.show()

# %% [markdown]
# Quais variáveis tem uma correlação positiva?
# Quais variáveis tem uma correlação negativa?

# %% [markdown]
# Lembrem-se que ***Correlação não implica em Causalidade***

# %% [markdown]
# # Perguntas para guiar a geração de hipóteses

# %% [markdown]
# - Qual o objetivo principal da análise?
# - Quais informações te chamaram mais atenção?
# - Como posso melhor explicar a variação em uma variável específica?
# - Existem diferenças significativas de acordo com um certo filtro ou recorte?
